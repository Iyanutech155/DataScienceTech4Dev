# %% [markdown]
# ## Answer the following questions using the wine review dataset from previous classd
# 1.Set the index of the dataframe to country
# 2.Using the index and any country of your choice, show the reviews for those country
# Sample code
# df.loc[df.country == 'Italy']
# can you glean any insight from this? Perhaps the percentage of wines from the selected country.
# 3.Supposing wines are reviewed on a 80-to-100 point scale, and wines with greater than 90 points are average, can you check what percentage of the total wines are above average? What about the percentage in the country you selected from question 2?
# 4.Check the pandas ‘isin’ operator and use it to perform any operation of your choice on the dataset
# 5.Suppose we'll buy any wine that's made in Italy or which is rated above average. Can you select or show these wines using the or (|) operator?
# 6.Read about the notnull operator and use it to check for wines whose prices are not null
# 7.Please share something you learnt outside of class on thursday

# %%
import pandas as pd

# %%
Wine_review = pd.read_csv ('Wine_review.csv')

# %%
Wine_review
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0      US  This tremendous 100% varietal wine hails from ...
# 1                1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                2      US  Mac Watson honors the memory of a wine once ma...
# 3                3      US  This spent 20 months in 30% new French oak, an...
# 4                4  France  This is the top wine from La Bégude, named aft...
# ...            ...     ...                                                ...
# 150925      150925   Italy  Many people feel Fiano represents southern Ita...
# 150926      150926  France  Offers an intriguing nose with ginger, lime an...
# 150927      150927   Italy  This classic example comes from a cru vineyard...
# 150928      150928  France  A perfect salmon shade, with scents of peaches...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
# ...

# %%
df.set_index ('country')
# Out:
#          Unnamed: 0                                        description  \
# country
# US                0  This tremendous 100% varietal wine hails from ...
# Spain             1  Ripe aromas of fig, blackberry and cassis are ...
# US                2  Mac Watson honors the memory of a wine once ma...
# US                3  This spent 20 months in 30% new French oak, an...
# France            4  This is the top wine from La Bégude, named aft...
# ...             ...                                                ...
# Italy        150925  Many people feel Fiano represents southern Ita...
# France       150926  Offers an intriguing nose with ginger, lime an...
# Italy        150927  This classic example comes from a cru vineyard...
# France       150928  A perfect salmon shade, with scents of peaches...
# Italy        150929  More Pinot Grigios should taste like this. A r...
#
#                                   designation  points  price  \
# country
# ...

# %%
df.loc[df.country == 'US']
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0      US  This tremendous 100% varietal wine hails from ...
# 2                2      US  Mac Watson honors the memory of a wine once ma...
# 3                3      US  This spent 20 months in 30% new French oak, an...
# 8                8      US  This re-named vineyard was formerly bottled as...
# 9                9      US  The producer sources from two blocks of the vi...
# ...            ...     ...                                                ...
# 150892      150892      US  A light, earthy wine, with violet, berry and t...
# 150896      150896      US  Some raspberry fruit in the aroma, but things ...
# 150914      150914      US  Old-gold in color, and thick and syrupy. The a...
# 150915      150915      US  Decades ago, Beringer’s then-winemaker Myron N...
# 150916      150916      US  An impressive wine that presents a full bouque...
#
# ...

# %%
df.loc[review.country == 'US']
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0      US  This tremendous 100% varietal wine hails from ...
# 2                2      US  Mac Watson honors the memory of a wine once ma...
# 3                3      US  This spent 20 months in 30% new French oak, an...
# 8                8      US  This re-named vineyard was formerly bottled as...
# 9                9      US  The producer sources from two blocks of the vi...
# ...            ...     ...                                                ...
# 150892      150892      US  A light, earthy wine, with violet, berry and t...
# 150896      150896      US  Some raspberry fruit in the aroma, but things ...
# 150914      150914      US  Old-gold in color, and thick and syrupy. The a...
# 150915      150915      US  Decades ago, Beringer’s then-winemaker Myron N...
# 150916      150916      US  An impressive wine that presents a full bouque...
#
# ...

# %% [markdown]
# Out of the 150,930 rows, 62,397 rows contains wine made in the US
# and that accounts for approximately 41% of the total wine.

# %%
df.loc[(review.country == 'US')&(review.points > 90)]
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0      US  This tremendous 100% varietal wine hails from ...
# 2                2      US  Mac Watson honors the memory of a wine once ma...
# 3                3      US  This spent 20 months in 30% new French oak, an...
# 8                8      US  This re-named vineyard was formerly bottled as...
# 9                9      US  The producer sources from two blocks of the vi...
# ...            ...     ...                                                ...
# 150778      150778      US  Deep, layered aromas of smoky honey, lees and ...
# 150780      150780      US  Very much in the vein of a super-oaked, ripe C...
# 150914      150914      US  Old-gold in color, and thick and syrupy. The a...
# 150915      150915      US  Decades ago, Beringer’s then-winemaker Myron N...
# 150916      150916      US  An impressive wine that presents a full bouque...
#
# ...

# %%
df.loc[review.country.isin(['Argentina','France','US'])]
df.loc[review.points.isin([94, 92, 91])]
df.loc[review.price.isin([30.0,25.0,24.0])]
# Out:
#         Unnamed: 0    country  \
# 20              20         US
# 45              45      Italy
# 57              57         US
# 58              58         US
# 60              60  Argentina
# ...            ...        ...
# 150913      150913     France
# 150914      150914         US
# 150915      150915         US
# 150917      150917     France
# 150923      150923     France
#
#                                               description  \
# 20      Heitz has made this stellar rosé from the rare...
# 45      A blend of 90% Sangiovese and 10% Canaiolo, th...
# 57      While exuberantly fruity, almost tropical on t...
# 58      Cabernet makes up just over half of this blend...
# 60      Concentrated, ripe blackberry and cassis aroma...
# ...                                                   ...
# 150913  Inky and rustic, yet in a refined manner. This...
# 150914  Old-gold in color, and thick and syrupy. The a...
# 150915  Decades ago, Beringer’s then-winemaker Myron N...
# ...

# %%
df.loc[(review.designation.notnull())]
df.loc[(review.points.notnull())]
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0      US  This tremendous 100% varietal wine hails from ...
# 1                1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                2      US  Mac Watson honors the memory of a wine once ma...
# 3                3      US  This spent 20 months in 30% new French oak, an...
# 4                4  France  This is the top wine from La Bégude, named aft...
# ...            ...     ...                                                ...
# 150925      150925   Italy  Many people feel Fiano represents southern Ita...
# 150926      150926  France  Offers an intriguing nose with ginger, lime an...
# 150927      150927   Italy  This classic example comes from a cru vineyard...
# 150928      150928  France  A perfect salmon shade, with scents of peaches...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
# ...

# %%
df.loc[review.price.isnull()]
# Out:
#         Unnamed: 0      country  \
# 32              32        Italy
# 56              56       France
# 72              72        Italy
# 82              82        Italy
# 116            116        Spain
# ...            ...          ...
# 150377      150377  New Zealand
# 150378      150378  New Zealand
# 150587      150587       Canada
# 150673      150673           US
# 150922      150922        Italy
#
#                                               description       designation  \
# 32      Underbrush, scorched earth, menthol and plum s...     Vigna Piaggia
# 56      Delicious while also young and textured, this ...           Le Pavé
# 72      This offers aromas of red rose, wild berry, da...    Bussia Riserva
# 82      Berry, baking spice, dried iris, mint and a hi...  Palliano Riserva
# 116     Aromas of brandied cherry and crème de cassis ...       Dulce Tinto
# ...                                                   ...               ...
# ...

# %% [markdown]
# Data cleaning means fixing bad data in your data set.
#
# Bad data could be:
#
# Empty cells
# Data in wrong format
# Wrong data
# Duplicates

# %% [markdown]
# ## Class Pandas- Groupby

# %%
review.groupby()
